# %%
import json
import matplotlib.pyplot as plt

# %%
f = open("./news_DB.json")

# %%
data = json.load(f)

# %%
print(data[0]['tag'])
# Out:
# ['Messi', 'Solskjaer', 'MU', 'Real Madrid', 'Iker Casillas', 'Dean Henderson', 'Barca']

# %%
cnt_tag = {}
total = 0
for news in data:
    for tag in news['tag']:
        cnt_tag[tag] = cnt_tag.get(tag, 0) + 1
        total += 1

# %%
list_tag = []
for key in cnt_tag:
    list_tag.append((key.upper(), cnt_tag[key]))

# %%
list_tag.sort(key = lambda x: x[1], reverse=True)

# %%
print(list_tag[0][1])
# Out:
# 285

# %%
width = 0.35

fig, ax = plt.subplots()

keys = []
values = []

for k,v in list_tag:
    keys.append(k)
    values.append(v)

fig.set_size_inches(18.5, 15)

print(keys[0])

ax.barh(keys[:20], values[:20], align='center', height=0.5)
# Out:
# MỸ
# <BarContainer object of 20 artists>

# %%
plt.show()

# %%
fig1, ax1 = plt.subplots()
sizes = []
total = 0
for i in range(20):
    total += values[i]

key_pies = keys[:20]
# key_pies.append('Others')

for i in range(20):
    sizes.append(values[i] / total)

ax1.pie(sizes, labels=keys[:20], shadow=True, startangle=90, radius=4)
# Out:
# ([<matplotlib.patches.Wedge at 0x269e7975bc8>,
#   <matplotlib.patches.Wedge at 0x269e7975fc8>,
#   <matplotlib.patches.Wedge at 0x269e797cf08>,
#   <matplotlib.patches.Wedge at 0x269e7981e88>,
#   <matplotlib.patches.Wedge at 0x269e798d748>,
#   <matplotlib.patches.Wedge at 0x269e7993788>,
#   <matplotlib.patches.Wedge at 0x269e7993e08>,
#   <matplotlib.patches.Wedge at 0x269e799ad88>,
#   <matplotlib.patches.Wedge at 0x269e7989e48>,
#   <matplotlib.patches.Wedge at 0x269e798de48>,
#   <matplotlib.patches.Wedge at 0x269e6a1f748>,
#   <matplotlib.patches.Wedge at 0x269e79b4a48>,
#   <matplotlib.patches.Wedge at 0x269e79ba9c8>,
#   <matplotlib.patches.Wedge at 0x269e79c1948>,
#   <matplotlib.patches.Wedge at 0x269e79c68c8>,
#   <matplotlib.patches.Wedge at 0x269e79cd848>,
#   <matplotlib.patches.Wedge at 0x269e79d27c8>,
#   <matplotlib.patches.Wedge at 0x269e79d9748>,
#   <matplotlib.patches.Wedge at 0x269e79e06c8>,
#   <matplotlib.patches.Wedge at 0x269e79e7648>],
#  [Text(-1.3219819219941473, 4.196708686330356, 'MỸ'),
#   Text(-3.4274328805049774, 2.759112873666707, 'TRUNG QUỐC'),
#   Text(-4.357441279671621, 0.6104961049947439, 'COVID-19'),
#   Text(-4.134647844564224, -1.5048877703803756, 'ĐÀ NẴNG'),
#   Text(-3.112935907275863, -3.1096028745151045, 'COVID-19'),
#   Text(-1.7887816169594197, -4.019982627677394, 'HÀ NỘI'),
#   Text(-0.43274212661044953, -4.378668091081655, 'VIRUS CORONA'),
#   Text(0.9258667615732139, -4.301484713423254, 'NGOẠI HẠNG ANH'),
#   Text(2.183657665412734, -3.8199004175873763, 'NGƯỜI LAO ĐỘNG'),
#   Text(3.2176334806666325, -3.0011389144944847, ' COVID-19,'),
#   Text(3.952211151086137, -1.933914945707384, 'PHÁP'),
#   Text(4.342613097332386, -0.7083159513079049, 'PREMIER LEAGUE'),
#   Text(4.367831925380863, 0.5310784044034412, ' PLO.VN'),
#   Text(4.085933222531792, 1.6325286218045205, 'COVID-19'),
#   Text(3.602918916851502, 2.5256633343724975, 'DONALD TRUMP'),
#   Text(3.0354196646971654, 3.185314342285507, 'APPLE'),
#   Text(2.424398530631201, 3.6718240378146225, 'TP. HỒ CHÍ MINH'),
#   Text(1.7456373236774065, 4.038904595826, 'IPHONE'),
#   Text(1.045248914896055, 4.274044303222491, 'HONDA'),
#   Text(0.34827607558503565, 4.38619468049186, 'MU')])
