# %%
import json
import matplotlib.pyplot as plt

# %%
f = open("./news_DB.json")

# %%
data = json.load(f)

# %%
print(data[0]['tag'])
# Out:
# ['Messi', 'Solskjaer', 'MU', 'Real Madrid', 'Iker Casillas', 'Dean Henderson', 'Barca']

# %%
cnt_tag = {}
total = 0
for news in data:
    for tag in news['tag']:
        cnt_tag[tag] = cnt_tag.get(tag, 0) + 1
        total += 1

# %%
list_tag = []
for key in cnt_tag:
    list_tag.append((key.upper(), cnt_tag[key]))

# %%
list_tag.sort(key = lambda x: x[1], reverse=True)

# %%
print(list_tag[0][1])
# Out:
# 285

# %%
width = 0.35

fig, ax = plt.subplots()

keys = []
values = []

for k,v in list_tag:
    keys.append(k)
    values.append(v)

fig.set_size_inches(18.5, 15)

print(keys[0])

ax.barh(keys[:20], values[:20], align='center', height=0.5)
# Out:
# MỸ
# <BarContainer object of 20 artists>

# %%
plt.show()
